# %%
from scav_switch.converters.pdf import ScavToMarkdown

# %%
file_path = '0000539-21.2022.8.27.2700.pdf'

# %%
converter = ScavToMarkdown(model="gpt-4.1", verbose=True)

r = converter.dig(file_path)
# Out:
# 2025-06-14 02:33:12,117 - scav_switch.converters.pdf.to_markdown.ScavToMarkdown - INFO - ScavToMarkdown initialized - Project: None
# 2025-06-14 02:33:12,117 - scav_switch.converters.pdf.to_markdown.ScavToMarkdown - INFO - Starting PDF to Markdown conversion process
# 2025-06-14 02:33:12,118 - scav_switch.converters.pdf.to_markdown.ScavToMarkdown - INFO - PDF loaded successfully - 467646 bytes
# 2025-06-14 02:33:12,479 - scav_switch.converters.pdf.to_markdown.ScavToMarkdown - INFO - Extracted 7 pages from PDF
# 2025-06-14 02:33:12,480 - scav_switch.converters.pdf.to_markdown.ScavToMarkdown - INFO - Starting parallel processing with 10 workers
# 2025-06-14 02:34:00,567 - scav_switch.converters.pdf.to_markdown.ScavToMarkdown - INFO - Conversion completed - 32349 characters generated

# %%
print(r)
# Out:
# 11/06/2025, 10:25                                                                                      Documento:4501195
#
# ------------------------------------------------------------------------------------------------------
#
#                                               Poder Judiciário
#                                             JUSTIÇA ESTADUAL
#                         Tribunal de Justiça do Estado do Tocantins
#          1ª Vara da Fazenda e Registros Públicos de Araguaína
#
# AVENIDA FILADÉLFIA, 3.650 - Bairro: SETOR DAS AUTARQUIAS ESTADUAIS - CEP: 77813-905 - Fone: (63)3501-1500 - Email: fazendalaraguaina@tjto.jus.br
#
# A(O) DESEMBARGADOR(A) PRESIDENTE DO TRIBUNAL DE JUSTIÇA DO ESTADO DO TOCANTINS
#
# JUÍZO REQUISITANTE: 1ª Vara da Fazenda e Registros Públicos de Araguaína
#
# OFÍCIO PRECATÓRIO Nº TOARA1EFAZ/2022/000186
#
# ...
